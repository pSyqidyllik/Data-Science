# %% [markdown]
# ### Sante, Cedrick C.
# ### BSCpE-3

# %% [markdown]
# ## SARIMA MODEL

# %%
# Import Library

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline

# %% [markdown]
# ### Data Source: Center for Disease Control (CDC) OPEN DATA

# %%
# COVID Data for Philippines (Select Specific Dates Only March 6, 2020 to April 22, 2021)

# Read Data Source (PH-COVID-UPDATED.csv)
covid = pd.read_csv('PH-COVID-UPDATED.csv', parse_dates = True)
covid['Date'] = pd.to_datetime(covid['Date'], format = '%m/%d/%Y')
covid.set_index('Date', inplace = True)
covid.index.freq = 'D' # set frequency to daily

# CODE1: Filter Specific Dates Only

filtered_dates = (covid.index >= '2020-03-06') & (covid.index <= '2021-03-22')
covid = covid.loc[filtered_dates]
covid
# Out:
#             Cases
# Date
# 2020-03-06      2
# 2020-03-07      1
# 2020-03-08      4
# 2020-03-09     10
# 2020-03-10     13
# ...           ...
# 2021-03-18   5286
# 2021-03-19   7082
# 2021-03-20   7990
# 2021-03-21   7738
# 2021-03-22   8019
#
# [382 rows x 1 columns]

# %%
# COVID Data for Philippines (Select Specific Dates Only March 6, 2020 to April 22, 2021)

# Read Data Source (PH-COVID-UPDATED.csv)
covid = pd.read_csv('PH-COVID-UPDATED.csv', parse_dates = True)
covid['Date'] = pd.to_datetime(covid['Date'], format = '%m/%d/%Y')
covid.set_index('Date', inplace = True)
covid.index.freq = 'D' # set frequency to daily

# CODE1: Filter Specific Dates Only
# Out:
#             Cases
# Date
# 2020-03-06      2
# 2020-03-07      1
# 2020-03-08      4
# 2020-03-09     10
# 2020-03-10     13
# ...           ...
# 2021-03-18   5286
# 2021-03-19   7082
# 2021-03-20   7990
# 2021-03-21   7738
# 2021-03-22   8019
#
# [382 rows x 1 columns]

# %% [markdown]
# ### Seasonal ARIMA

# %%
# CODE 2: Import SARIMAX Library from statsmodels

from statsmodels.tsa.statespace.sarimax import SARIMAX

# %%
# CODE 3: Show Time-Series ETS Decomposition, using additive model

from statsmodels.tsa.seasonal import seasonal_decompose
result = seasonal_decompose(covid['Cases'], model='additive')
result.plot();

# %%
# CODE 3: Show Time-Series ETS Decomposition, using additive model

# %%
# CODE 4: Train, Test Split (280 Training Size, The rest are testing)

train = covid.iloc[:280]
test = covid.iloc[280:]

# %%
# CODE 5: Show Training data

train
# Out:
#             Cases
# Date
# 2020-03-06      2
# 2020-03-07      1
# 2020-03-08      4
# 2020-03-09     10
# 2020-03-10     13
# ...           ...
# 2020-12-06   1765
# 2020-12-07   1565
# 2020-12-08   1386
# 2020-12-09   1379
# 2020-12-10   1376
#
# [280 rows x 1 columns]

# %%
# CODE 5: Show Training data
# Out:
#             Cases
# Date
# 2020-03-06      2
# 2020-03-07      1
# 2020-03-08      4
# 2020-03-09     10
# 2020-03-10     13
# ...           ...
# 2020-12-06   1765
# 2020-12-07   1565
# 2020-12-08   1386
# 2020-12-09   1379
# 2020-12-10   1376
#
# [280 rows x 1 columns]

# %%
# CODE 6: Install PMD ARIMA (You may need to restart if you are using Google Collab)

# !pip install pmdarima
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting pmdarima
#   Downloading pmdarima-1.8.5-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.manylinux_2_24_x86_64.whl (1.4 MB)
#      |████████████████████████████████| 1.4 MB 5.0 MB/s
# Requirement already satisfied: urllib3 in /usr/local/lib/python3.7/dist-packages (from pmdarima) (1.24.3)
# Requirement already satisfied: Cython!=0.29.18,>=0.29 in /usr/local/lib/python3.7/dist-packages (from pmdarima) (0.29.30)
# Requirement already satisfied: pandas>=0.19 in /usr/local/lib/python3.7/dist-packages (from pmdarima) (1.3.5)
# Collecting statsmodels!=0.12.0,>=0.11
#   Downloading statsmodels-0.13.2-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (9.8 MB)
#      |████████████████████████████████| 9.8 MB 45.3 MB/s
# Requirement already satisfied: numpy>=1.19.3 in /usr/local/lib/python3.7/dist-packages (from pmdarima) (1.21.6)
# Requirement already satisfied: scipy>=1.3.2 in /usr/local/lib/python3.7/dist-packages (from pmdarima) (1.4.1)
# Requirement already satisfied: setuptools!=50.0.0,>=38.6.0 in /usr/local/lib/python3.7/dist-packages (from pmdarima) (57.4.0)
# Requirement already satisfied: scikit-learn>=0.22 in /usr/local/lib/python3.7/dist-packages (from pmdarima) (1.0.2)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.7/dist-packages (from pmdarima) (1.1.0)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.19->pmdarima) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.19->pmdarima) (2022.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->pandas>=0.19->pmdarima) (1.15.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from scikit-learn>=0.22->pmdarima) (3.1.0)
# Requirement already satisfied: patsy>=0.5.2 in /usr/local/lib/python3.7/dist-packages (from statsmodels!=0.12.0,>=0.11->pmdarima) (0.5.2)
# Requirement already satisfied: packaging>=21.3 in /usr/local/lib/python3.7/dist-packages (from statsmodels!=0.12.0,>=0.11->pmdarima) (21.3)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging>=21.3->statsmodels!=0.12.0,>=0.11->pmdarima) (3.0.9)
# Installing collected packages: statsmodels, pmdarima
#   Attempting uninstall: statsmodels
#     Found existing installation: statsmodels 0.10.2
#     Uninstalling statsmodels-0.10.2:
#       Successfully uninstalled statsmodels-0.10.2
# Successfully installed pmdarima-1.8.5 statsmodels-0.13.2

# %%
# CODE 6: Install PMD ARIMA (You may need to restart if you are using Google Collab)
# Out:
# Requirement already satisfied: pmdarima in /usr/local/lib/python3.7/dist-packages (1.8.2)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.7/dist-packages (from pmdarima) (1.0.1)
# Requirement already satisfied: urllib3 in /usr/local/lib/python3.7/dist-packages (from pmdarima) (1.24.3)
# Requirement already satisfied: scikit-learn>=0.22 in /usr/local/lib/python3.7/dist-packages (from pmdarima) (0.22.2.post1)
# Requirement already satisfied: statsmodels!=0.12.0,>=0.11 in /usr/local/lib/python3.7/dist-packages (from pmdarima) (0.12.2)
# Requirement already satisfied: setuptools!=50.0.0,>=38.6.0 in /usr/local/lib/python3.7/dist-packages (from pmdarima) (57.0.0)
# Requirement already satisfied: Cython!=0.29.18,>=0.29 in /usr/local/lib/python3.7/dist-packages (from pmdarima) (0.29.23)
# Requirement already satisfied: pandas>=0.19 in /usr/local/lib/python3.7/dist-packages (from pmdarima) (1.1.5)
# Requirement already satisfied: numpy~=1.19.0 in /usr/local/lib/python3.7/dist-packages (from pmdarima) (1.19.5)
# Requirement already satisfied: scipy>=1.3.2 in /usr/local/lib/python3.7/dist-packages (from pmdarima) (1.4.1)
# Requirement already satisfied: patsy>=0.5 in /usr/local/lib/python3.7/dist-packages (from statsmodels!=0.12.0,>=0.11->pmdarima) (0.5.1)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.19->pmdarima) (2.8.1)
# Requirement already satisfied: pytz>=2017.2 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.19->pmdarima) (2018.9)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from patsy>=0.5->statsmodels!=0.12.0,>=0.11->pmdarima) (1.15.0)

# %%
# Find the best SARIMAX parameters using auto_arima, (with trace = True, seasonal = True, m = 7)
# Need to Import auto_arima

from pmdarima.arima import auto_arima

stepwise_fit = auto_arima(covid, trace = True, seasonal = True, m = 7) # this is already the code
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(2,1,2)(1,0,1)[7] intercept   : AIC=5905.702, Time=2.05 sec
#  ARIMA(0,1,0)(0,0,0)[7] intercept   : AIC=6057.853, Time=0.02 sec
#  ARIMA(1,1,0)(1,0,0)[7] intercept   : AIC=5946.129, Time=0.16 sec
#  ARIMA(0,1,1)(0,0,1)[7] intercept   : AIC=5944.360, Time=0.65 sec
#  ARIMA(0,1,0)(0,0,0)[7]             : AIC=6056.216, Time=0.01 sec
#  ARIMA(2,1,2)(0,0,1)[7] intercept   : AIC=5924.284, Time=1.08 sec
#  ARIMA(2,1,2)(1,0,0)[7] intercept   : AIC=5923.248, Time=1.10 sec
#  ARIMA(2,1,2)(2,0,1)[7] intercept   : AIC=5906.731, Time=3.28 sec
#  ARIMA(2,1,2)(1,0,2)[7] intercept   : AIC=5907.780, Time=3.15 sec
#  ARIMA(2,1,2)(0,0,0)[7] intercept   : AIC=5924.940, Time=0.49 sec
#  ARIMA(2,1,2)(0,0,2)[7] intercept   : AIC=5916.238, Time=2.11 sec
#  ARIMA(2,1,2)(2,0,0)[7] intercept   : AIC=5914.126, Time=1.77 sec
#  ARIMA(2,1,2)(2,0,2)[7] intercept   : AIC=5908.584, Time=3.63 sec
#  ARIMA(1,1,2)(1,0,1)[7] intercept   : AIC=5904.616, Time=1.96 sec
#  ARIMA(1,1,2)(0,0,1)[7] intercept   : AIC=5927.690, Time=0.80 sec
#  ARIMA(1,1,2)(1,0,0)[7] intercept   : AIC=5926.731, Time=0.35 sec
#  ARIMA(1,1,2)(2,0,1)[7] intercept   : AIC=5905.892, Time=2.55 sec
#  ARIMA(1,1,2)(1,0,2)[7] intercept   : AIC=5906.043, Time=3.30 sec
#  ARIMA(1,1,2)(0,0,0)[7] intercept   : AIC=5928.882, Time=0.35 sec
#  ARIMA(1,1,2)(0,0,2)[7] intercept   : AIC=5919.289, Time=1.81 sec
#  ARIMA(1,1,2)(2,0,0)[7] intercept   : AIC=5916.340, Time=1.40 sec
#  ARIMA(1,1,2)(2,0,2)[7] intercept   : AIC=5907.022, Time=3.49 sec
#  ARIMA(0,1,2)(1,0,1)[7] intercept   : AIC=5947.130, Time=1.12 sec
#  ARIMA(1,1,1)(1,0,1)[7] intercept   : AIC=5919.815, Time=1.40 sec
#  ARIMA(1,1,3)(1,0,1)[7] intercept   : AIC=5905.185, Time=2.04 sec
#  ARIMA(0,1,1)(1,0,1)[7] intercept   : AIC=5945.760, Time=0.95 sec
#  ARIMA(0,1,3)(1,0,1)[7] intercept   : AIC=inf, Time=1.46 sec
#  ARIMA(2,1,1)(1,0,1)[7] intercept   : AIC=inf, Time=1.30 sec
#  ARIMA(2,1,3)(1,0,1)[7] intercept   : AIC=5902.042, Time=2.30 sec
#  ARIMA(2,1,3)(0,0,1)[7] intercept   : AIC=5925.956, Time=1.62 sec
#  ARIMA(2,1,3)(1,0,0)[7] intercept   : AIC=5925.085, Time=1.58 sec
#  ARIMA(2,1,3)(2,0,1)[7] intercept   : AIC=5902.390, Time=3.52 sec
#  ARIMA(2,1,3)(1,0,2)[7] intercept   : AIC=5904.362, Time=4.37 sec
#  ARIMA(2,1,3)(0,0,0)[7] intercept   : AIC=5926.449, Time=0.41 sec
#  ARIMA(2,1,3)(0,0,2)[7] intercept   : AIC=5917.330, Time=3.04 sec
#  ARIMA(2,1,3)(2,0,0)[7] intercept   : AIC=5911.350, Time=3.17 sec
#  ARIMA(2,1,3)(2,0,2)[7] intercept   : AIC=5908.173, Time=4.55 sec
#  ARIMA(3,1,3)(1,0,1)[7] intercept   : AIC=5910.562, Time=2.47 sec
#  ARIMA(2,1,4)(1,0,1)[7] intercept   : AIC=inf, Time=2.66 sec
#  ARIMA(1,1,4)(1,0,1)[7] intercept   : AIC=5906.416, Time=2.49 sec
#  ARIMA(3,1,2)(1,0,1)[7] intercept   : AIC=5908.787, Time=2.19 sec
#  ARIMA(3,1,4)(1,0,1)[7] intercept   : AIC=5906.396, Time=3.48 sec
#  ARIMA(2,1,3)(1,0,1)[7]             : AIC=5900.493, Time=1.90 sec
#  ARIMA(2,1,3)(0,0,1)[7]             : AIC=5926.398, Time=0.47 sec
#  ARIMA(2,1,3)(1,0,0)[7]             : AIC=5925.114, Time=0.75 sec
#  ARIMA(2,1,3)(2,0,1)[7]             : AIC=5901.456, Time=3.05 sec
#  ARIMA(2,1,3)(1,0,2)[7]             : AIC=5901.169, Time=3.44 sec
#  ARIMA(2,1,3)(0,0,0)[7]             : AIC=5926.601, Time=0.22 sec
#  ARIMA(2,1,3)(0,0,2)[7]             : AIC=5917.342, Time=2.02 sec
#  ARIMA(2,1,3)(2,0,0)[7]             : AIC=5911.079, Time=1.81 sec
#  ARIMA(2,1,3)(2,0,2)[7]             : AIC=5903.665, Time=4.05 sec
#  ARIMA(1,1,3)(1,0,1)[7]             : AIC=5903.401, Time=1.80 sec
#  ARIMA(2,1,2)(1,0,1)[7]             : AIC=5903.793, Time=1.68 sec
#  ARIMA(3,1,3)(1,0,1)[7]             : AIC=5905.479, Time=1.87 sec
#  ARIMA(2,1,4)(1,0,1)[7]             : AIC=5905.729, Time=2.19 sec
#  ARIMA(1,1,2)(1,0,1)[7]             : AIC=5903.002, Time=1.04 sec
#  ARIMA(1,1,4)(1,0,1)[7]             : AIC=5904.457, Time=2.22 sec
#  ARIMA(3,1,2)(1,0,1)[7]             : AIC=5905.087, Time=1.84 sec
#  ARIMA(3,1,4)(1,0,1)[7]             : AIC=inf, Time=2.58 sec
#
# Best model:  ARIMA(2,1,3)(1,0,1)[7]
# Total fit time: 114.742 seconds

# %%
# Find the best SARIMAX parameters using auto_arima, (with trace = True, seasonal = True, m = 7)
# Need to Import auto_arima

from pmdarima.arima import auto_arima

stepwise_fit = auto_arima(covid, trace = True, seasonal = True, m = 7) # this is already the code
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(2,1,2)(1,0,1)[7] intercept   : AIC=5905.702, Time=2.14 sec
#  ARIMA(0,1,0)(0,0,0)[7] intercept   : AIC=6057.853, Time=0.02 sec
#  ARIMA(1,1,0)(1,0,0)[7] intercept   : AIC=5946.129, Time=0.15 sec
#  ARIMA(0,1,1)(0,0,1)[7] intercept   : AIC=5944.360, Time=0.65 sec
#  ARIMA(0,1,0)(0,0,0)[7]             : AIC=6056.216, Time=0.02 sec
#  ARIMA(2,1,2)(0,0,1)[7] intercept   : AIC=5924.284, Time=1.13 sec
#  ARIMA(2,1,2)(1,0,0)[7] intercept   : AIC=5923.248, Time=1.11 sec
#  ARIMA(2,1,2)(2,0,1)[7] intercept   : AIC=5906.731, Time=3.27 sec
#  ARIMA(2,1,2)(1,0,2)[7] intercept   : AIC=5907.780, Time=3.22 sec
#  ARIMA(2,1,2)(0,0,0)[7] intercept   : AIC=5924.940, Time=0.60 sec
#  ARIMA(2,1,2)(0,0,2)[7] intercept   : AIC=5916.238, Time=2.18 sec
#  ARIMA(2,1,2)(2,0,0)[7] intercept   : AIC=5914.126, Time=1.79 sec
#  ARIMA(2,1,2)(2,0,2)[7] intercept   : AIC=5908.584, Time=3.59 sec
#  ARIMA(1,1,2)(1,0,1)[7] intercept   : AIC=5904.616, Time=1.91 sec
#  ARIMA(1,1,2)(0,0,1)[7] intercept   : AIC=5927.690, Time=0.79 sec
#  ARIMA(1,1,2)(1,0,0)[7] intercept   : AIC=5926.731, Time=0.35 sec
#  ARIMA(1,1,2)(2,0,1)[7] intercept   : AIC=5905.892, Time=2.61 sec
#  ARIMA(1,1,2)(1,0,2)[7] intercept   : AIC=5906.043, Time=3.30 sec
#  ARIMA(1,1,2)(0,0,0)[7] intercept   : AIC=5928.882, Time=0.38 sec
#  ARIMA(1,1,2)(0,0,2)[7] intercept   : AIC=5919.289, Time=1.84 sec
#  ARIMA(1,1,2)(2,0,0)[7] intercept   : AIC=5916.340, Time=1.43 sec
#  ARIMA(1,1,2)(2,0,2)[7] intercept   : AIC=5907.022, Time=3.53 sec
#  ARIMA(0,1,2)(1,0,1)[7] intercept   : AIC=5947.130, Time=1.10 sec
#  ARIMA(1,1,1)(1,0,1)[7] intercept   : AIC=5919.815, Time=1.42 sec
#  ARIMA(1,1,3)(1,0,1)[7] intercept   : AIC=5905.185, Time=2.03 sec
#  ARIMA(0,1,1)(1,0,1)[7] intercept   : AIC=5945.760, Time=0.95 sec
#  ARIMA(0,1,3)(1,0,1)[7] intercept   : AIC=inf, Time=1.46 sec
#  ARIMA(2,1,1)(1,0,1)[7] intercept   : AIC=inf, Time=1.33 sec
#  ARIMA(2,1,3)(1,0,1)[7] intercept   : AIC=5902.042, Time=2.39 sec
#  ARIMA(2,1,3)(0,0,1)[7] intercept   : AIC=5925.956, Time=1.63 sec
#  ARIMA(2,1,3)(1,0,0)[7] intercept   : AIC=5925.085, Time=1.62 sec
#  ARIMA(2,1,3)(2,0,1)[7] intercept   : AIC=5902.390, Time=3.57 sec
#  ARIMA(2,1,3)(1,0,2)[7] intercept   : AIC=5904.362, Time=4.49 sec
#  ARIMA(2,1,3)(0,0,0)[7] intercept   : AIC=5926.449, Time=0.50 sec
#  ARIMA(2,1,3)(0,0,2)[7] intercept   : AIC=5917.330, Time=3.08 sec
#  ARIMA(2,1,3)(2,0,0)[7] intercept   : AIC=5911.350, Time=3.24 sec
#  ARIMA(2,1,3)(2,0,2)[7] intercept   : AIC=5908.173, Time=4.56 sec
#  ARIMA(3,1,3)(1,0,1)[7] intercept   : AIC=5910.562, Time=2.53 sec
#  ARIMA(2,1,4)(1,0,1)[7] intercept   : AIC=inf, Time=2.74 sec
#  ARIMA(1,1,4)(1,0,1)[7] intercept   : AIC=5906.416, Time=2.60 sec
#  ARIMA(3,1,2)(1,0,1)[7] intercept   : AIC=5908.787, Time=2.13 sec
#  ARIMA(3,1,4)(1,0,1)[7] intercept   : AIC=5906.396, Time=3.42 sec
#  ARIMA(2,1,3)(1,0,1)[7]             : AIC=5900.493, Time=1.96 sec
#  ARIMA(2,1,3)(0,0,1)[7]             : AIC=5926.398, Time=0.49 sec
#  ARIMA(2,1,3)(1,0,0)[7]             : AIC=5925.114, Time=0.85 sec
#  ARIMA(2,1,3)(2,0,1)[7]             : AIC=5901.456, Time=3.05 sec
#  ARIMA(2,1,3)(1,0,2)[7]             : AIC=5901.169, Time=3.44 sec
#  ARIMA(2,1,3)(0,0,0)[7]             : AIC=5926.601, Time=0.25 sec
#  ARIMA(2,1,3)(0,0,2)[7]             : AIC=5917.342, Time=2.04 sec
#  ARIMA(2,1,3)(2,0,0)[7]             : AIC=5911.079, Time=1.89 sec
#  ARIMA(2,1,3)(2,0,2)[7]             : AIC=5903.665, Time=4.05 sec
#  ARIMA(1,1,3)(1,0,1)[7]             : AIC=5903.401, Time=1.78 sec
#  ARIMA(2,1,2)(1,0,1)[7]             : AIC=5903.793, Time=1.65 sec
#  ARIMA(3,1,3)(1,0,1)[7]             : AIC=5905.479, Time=1.93 sec
#  ARIMA(2,1,4)(1,0,1)[7]             : AIC=5905.729, Time=2.26 sec
#  ARIMA(1,1,2)(1,0,1)[7]             : AIC=5903.002, Time=1.11 sec
#  ARIMA(1,1,4)(1,0,1)[7]             : AIC=5904.457, Time=2.23 sec
#  ARIMA(3,1,2)(1,0,1)[7]             : AIC=5905.087, Time=1.82 sec
#  ARIMA(3,1,4)(1,0,1)[7]             : AIC=inf, Time=2.58 sec
#
# Best model:  ARIMA(2,1,3)(1,0,1)[7]
# Total fit time: 116.310 seconds

# %% [markdown]
# # Using only Training Data in SARIMAX model fit

# %%
# CODE 7: Model (Fit a model based on the identified best results of the auto_arima)

from statsmodels.tsa.statespace.sarimax import SARIMAX
model = SARIMAX(train, order=(2,1,3), seasonal_order=(1,0,1,7))

# %%
# CODE 8: Fit the Model (model.fit)

results = model.fit()

# %%
# CODE 8: Fit the Model (model.fit)
# Out:
# /usr/local/lib/python3.7/dist-packages/statsmodels/base/model.py:568: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)

# %%
# Results Summary

results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                       SARIMAX Results
# ===========================================================================================
# Dep. Variable:                               Cases   No. Observations:                  280
# Model:             SARIMAX(2, 1, 3)x(1, 0, [1], 7)   Log Likelihood               -2165.984
# Date:                             Wed, 06 Jul 2022   AIC                           4347.968
# Time:                                     09:09:07   BIC                           4377.018
# Sample:                                 03-06-2020   HQIC                          4359.622
#                                       - 12-10-2020
# Covariance Type:                               opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1         -1.3769      0.267     -5.150      0.000      -1.901      -0.853
# ar.L2         -0.5312      0.230     -2.306      0.021      -0.983      -0.080
# ma.L1          0.6636      0.259      2.559      0.010       0.155       1.172
# ma.L2         -0.3048      0.067     -4.568      0.000      -0.436      -0.174
# ma.L3         -0.3916      0.119     -3.283      0.001      -0.625      -0.158
# ar.S.L7       -0.6769      0.263     -2.575      0.010      -1.192      -0.162
# ma.S.L7        0.5918      0.295      2.003      0.045       0.013       1.171
# sigma2      3.238e+05    1.7e+04     19.047      0.000     2.9e+05    3.57e+05
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.01   Jarque-Bera (JB):               282.65
# Prob(Q):                              0.94   Prob(JB):                         0.00
# Heteroskedasticity (H):              15.86   Skew:                             0.57
# Prob(H) (two-sided):                  0.00   Kurtosis:                         7.80
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# """

# %%
# Results Summary

results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                       SARIMAX Results
# ===========================================================================================
# Dep. Variable:                               Cases   No. Observations:                  382
# Model:             SARIMAX(2, 1, 3)x(1, 0, [1], 7)   Log Likelihood               -2942.247
# Date:                             Tue, 15 Jun 2021   AIC                           5900.493
# Time:                                     08:22:52   BIC                           5932.036
# Sample:                                 03-06-2020   HQIC                          5913.008
#                                       - 03-22-2021
# Covariance Type:                               opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1         -1.6993      0.049    -34.753      0.000      -1.795      -1.603
# ar.L2         -0.8351      0.045    -18.591      0.000      -0.923      -0.747
# ma.L1          1.1250      0.051     21.919      0.000       1.024       1.226
# ma.L2         -0.0819      0.049     -1.663      0.096      -0.178       0.015
# ma.L3         -0.5168      0.033    -15.430      0.000      -0.582      -0.451
# ar.S.L7        0.9662      0.050     19.313      0.000       0.868       1.064
# ma.S.L7       -0.8651      0.073    -11.846      0.000      -1.008      -0.722
# sigma2      2.955e+05   1.19e+04     24.867      0.000    2.72e+05    3.19e+05
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.31   Jarque-Bera (JB):               468.64
# Prob(Q):                              0.58   Prob(JB):                         0.00
# Heteroskedasticity (H):               2.88   Skew:                             0.53
# Prob(H) (two-sided):                  0.00   Kurtosis:                         8.33
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# """

# %%
# CODE 9: Predictions

start = len(train)
end = len(train) + len(test) - 1
predictions = results.predict(start = start, end = end, typ = 'level')

# %%
# CODE 10: Plot the Model Fit

test.plot(legend = True, figsize = (20,5), title = 'SARIMA Model Test Data and Predictions')
predictions.plot(legend = True, label = 'SARIMA Predictions')

# %%
# CODE 10: Plot the Model Fit

# %% [markdown]
# # Using All Data in SARIMAX model fit

# %%
# CODE 7: Model (Fit a model based on the identified best results of the auto_arima)

model = SARIMAX(covid, order=(2,1,3), seasonal_order=(1,0,1,7))

# %%
# CODE 8: Fit the Model (model.fit)

results = model.fit()

# %%
# CODE 8: Fit the Model (model.fit)
# Out:
# /usr/local/lib/python3.7/dist-packages/statsmodels/base/model.py:568: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)

# %%
# Results Summary

results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                       SARIMAX Results
# ===========================================================================================
# Dep. Variable:                               Cases   No. Observations:                  382
# Model:             SARIMAX(2, 1, 3)x(1, 0, [1], 7)   Log Likelihood               -2942.255
# Date:                             Wed, 06 Jul 2022   AIC                           5900.510
# Time:                                     09:09:53   BIC                           5932.052
# Sample:                                 03-06-2020   HQIC                          5913.025
#                                       - 03-22-2021
# Covariance Type:                               opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1         -1.6984      0.049    -34.669      0.000      -1.794      -1.602
# ar.L2         -0.8348      0.045    -18.536      0.000      -0.923      -0.747
# ma.L1          1.1245      0.051     21.877      0.000       1.024       1.225
# ma.L2         -0.0824      0.049     -1.673      0.094      -0.179       0.014
# ma.L3         -0.5175      0.034    -15.445      0.000      -0.583      -0.452
# ar.S.L7        0.9663      0.050     19.323      0.000       0.868       1.064
# ma.S.L7       -0.8652      0.073    -11.846      0.000      -1.008      -0.722
# sigma2      2.956e+05   1.19e+04     24.852      0.000    2.72e+05    3.19e+05
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.32   Jarque-Bera (JB):               469.57
# Prob(Q):                              0.57   Prob(JB):                         0.00
# Heteroskedasticity (H):               2.88   Skew:                             0.53
# Prob(H) (two-sided):                  0.00   Kurtosis:                         8.33
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# """

# %%
# Results Summary

results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                       SARIMAX Results
# ===========================================================================================
# Dep. Variable:                               Cases   No. Observations:                  382
# Model:             SARIMAX(2, 1, 3)x(1, 0, [1], 7)   Log Likelihood               -2942.247
# Date:                             Tue, 15 Jun 2021   AIC                           5900.493
# Time:                                     08:22:52   BIC                           5932.036
# Sample:                                 03-06-2020   HQIC                          5913.008
#                                       - 03-22-2021
# Covariance Type:                               opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1         -1.6993      0.049    -34.753      0.000      -1.795      -1.603
# ar.L2         -0.8351      0.045    -18.591      0.000      -0.923      -0.747
# ma.L1          1.1250      0.051     21.919      0.000       1.024       1.226
# ma.L2         -0.0819      0.049     -1.663      0.096      -0.178       0.015
# ma.L3         -0.5168      0.033    -15.430      0.000      -0.582      -0.451
# ar.S.L7        0.9662      0.050     19.313      0.000       0.868       1.064
# ma.S.L7       -0.8651      0.073    -11.846      0.000      -1.008      -0.722
# sigma2      2.955e+05   1.19e+04     24.867      0.000    2.72e+05    3.19e+05
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.31   Jarque-Bera (JB):               468.64
# Prob(Q):                              0.58   Prob(JB):                         0.00
# Heteroskedasticity (H):               2.88   Skew:                             0.53
# Prob(H) (two-sided):                  0.00   Kurtosis:                         8.33
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# """

# %%
# CODE 9: Predictions

start = len(train)
end = len(train) + len(test) - 1
predictions = results.predict(start = start, end = end, typ = 'level')

# %%
# CODE 10: Plot the Model Fit

test.plot(legend = True, figsize = (20,5), title = 'SARIMA Model Test Data and Predictions')
predictions.plot(legend = True, label = 'SARIMA Predictions')

# %%
# CODE 10: Plot the Model Fit

# %%
# CODE 11: Forecast into Unknown Future
# SARIMA Model

model = SARIMAX(covid, order=(2,1,3), seasonal_order=(1,0,1,7))

# %%
# CODE 12: Fit the Model (All Data)

results = model.fit()

# %%
# CODE 12: Fit the Model (All Data)
# Out:
# /usr/local/lib/python3.7/dist-packages/statsmodels/base/model.py:568: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)

# %%
# CODE 13: Forecast

start = len(covid)
end = len(covid)+15
predictions = results.predict(start = start, end = end, typ = 'level')
predictions
# Out:
# 2021-03-23    7128.350025
# 2021-03-24    7358.287091
# 2021-03-25    7430.848535
# 2021-03-26    8169.927519
# 2021-03-27    8073.576950
# 2021-03-28    8152.819225
# 2021-03-29    8062.040442
# 2021-03-30    7724.940105
# 2021-03-31    7800.109541
# 2021-04-01    8019.787007
# 2021-04-02    8602.693440
# 2021-04-03    8607.709425
# 2021-04-04    8627.223630
# 2021-04-05    8554.502051
# 2021-04-06    8250.910863
# 2021-04-07    8273.395919
# Freq: D, Name: predicted_mean, dtype: float64

# %%
# CODE 13: Forecast
# Out:
# 2021-03-23    7129.254452
# 2021-03-24    7360.122675
# 2021-03-25    7431.344781
# 2021-03-26    8171.251499
# 2021-03-27    8073.488591
# 2021-03-28    8154.183150
# 2021-03-29    8062.058946
# 2021-03-30    7726.549264
# 2021-03-31    7800.857156
# 2021-04-01    8020.691324
# 2021-04-02    8603.218930
# 2021-04-03    8607.616527
# 2021-04-04    8628.155316
# 2021-04-05    8554.176699
# 2021-04-06    8252.410244
# 2021-04-07    8273.566911
# Freq: D, Name: SARIMA (1,1,1) (1,0,1,7) FORECAST, dtype: float64

# %%
# CODE 14: Plot SARIMA

plt.figure(figsize = (20,5))
plt.plot(covid['Cases'], color = 'r', label = 'Actual Cases (Infected)')
plt.plot(predictions, color = 'k', label = 'SARIMA FORECAST (+15 Days)')
plt.title('Philippines COVID-19 Cases', fontweight = 'bold')
plt.xlabel('\nDate')
plt.ylabel('Cases')
plt.grid(True)
plt.legend()
plt.show()

# %%
# CODE 14: Plot SARIMA

# %%
# CODE 15: Evaluation (RMSE), evaluate test_data vs predictions

from statsmodels.tools.eval_measures import rmse
error = rmse(test['Cases'], predictions)
error
# Out:
# 452.9734449995181

# %%
# CODE 15: Evaluation (RMSE), evaluate test_data vs predictions
# Out:
# 453.00368317086895
